# %%
import pandas as pd

# %%
df = pd.read_parquet("pfam_output/1-cysPrx_C.parquet")

# %%
df
# Out:
#     state    mode        A        C        D        E        F        G  \
# 0   COMPO   match  2.28046  4.31208  2.83393  2.63913  3.90855  2.69988
# 0   COMPO  insert  2.68618  4.42225  2.77519  2.73123  3.46354  2.40513
# 0   COMPO  delete      NaN      NaN      NaN      NaN      NaN      NaN
# 0       1   match  0.29666  6.14436  6.78514  6.79783  7.06332  2.55785
# 0       1  insert  2.68618  4.42225  2.77519  2.73123  3.46354  2.40513
# ..    ...     ...      ...      ...      ...      ...      ...      ...
# 0      39  insert  2.68618  4.42225  2.77519  2.73123  3.46354  2.40513
# 0      39  delete      NaN      NaN      NaN      NaN      NaN      NaN
# 0      40   match  3.21541  6.27102  3.40631  3.09986  5.61658  1.23219
# 0      40  insert  2.68618  4.42225  2.77519  2.73123  3.46354  2.40513
# 0      40  delete      NaN      NaN      NaN      NaN      NaN      NaN
#
#           H        I  ...        W        Y     m->m     m->i     m->d  \
# ...
